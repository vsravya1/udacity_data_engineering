# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM airports limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('TKI', 'Tokeen Seaplane Base', 'seaplane_base', '57A', '-133.32699585, 55.9370994568', 'TOKEEN', nan, 'NaN', 'US', 'US-AK', 'Tokeen', '57A'),
#  ('BKF', 'Lake Brooks Seaplane Base', 'seaplane_base', '5Z9', '-155.77699279785, 58.554798126221', 'No PORT Code (BKF)', 36.0, 'NaN', 'US', 'US-AK', 'Katmai National Park', '5Z9'),
#  ('AXB', 'Maxson Airfield', 'small_airport', '89NY', '-75.90034, 44.312002', 'ALEXANDRIA BAY', 340.0, 'NaN', 'US', 'US-NY', 'Alexandria Bay', '89NY'),
#  ('FRE', 'Fera/Maringe Airport', 'small_airport', 'NaN', '159.576996, -8.1075', 'FRESNO', nan, 'OC', 'SB', 'SB-IS', 'Fera Island', 'AGGF'),
#  ('ANZ', 'Angus Downs Airport', 'small_airport', 'NaN', '132.2748, -25.0325', 'ANZALDUAS', 1724.0, 'OC', 'AU', 'AU-NT', 'Angus Downs Station', 'NaN')]

# %%
# %sql select count(*) from immigrations;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(2306754,)]

# %%
# %sql  from ports
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1320 rows affected.
# []

# %%
# %sql select count(*) from temperature
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(0,)]

# %%
# %sql select visatype,count(*) from immigrations group by visatype  order by count(*) desc limit 5
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('WT', 985803),
#  ('B2', 867840),
#  ('WB', 172412),
#  ('B1', 167067),
#  ('GMT', 67120)]

# %%
# %sql select iata, port_city, port_state,count(*) from immigrations i join ports p on p.port_code=i.iata  group by iata, port_city, port_state order by count(*) desc limit 10
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [('NYC', 'NEW YORK', ' NY', 374318),
#  ('MIA', 'MIAMI', ' FL', 277355),
#  ('LOS', 'LOS ANGELES', ' CA', 238204),
#  ('SFR', 'SAN FRANCISCO', ' CA', 131580),
#  ('NEW', 'NEWARK/TETERBORO', ' NJ', 127034),
#  ('ORL', 'ORLANDO', ' FL', 116442),
#  ('HHW', 'HONOLULU', ' HI', 110571),
#  ('CHI', 'CHICAGO', ' IL', 98292),
#  ('HOU', 'HOUSTON', ' TX', 83856),
#  ('FTL', 'FORT LAUDERDALE', ' FL', 76490)]

# %%
# %sql select max(average_temperature) avg_temp,city from temperature group by city
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 248 rows affected.
# [(23.106, 'Corona'),
#  (34.379, 'Glendale'),
#  (27.751, 'Manchester'),
#  (23.106, 'Anaheim'),
#  (23.106, 'Escondido'),
#  (32.606, 'North Las Vegas'),
#  (30.134, 'Miramar'),
#  (34.379, 'Tempe'),
#  (23.106, 'San Diego'),
#  (27.336, 'Burbank'),
#  (29.759, 'Lubbock'),
#  (31.518, 'Houston'),
#  (28.128, 'Rockford'),
#  (30.134, 'Coral Springs'),
#  (24.511, 'Denver'),
#  (30.591, 'Ontario'),
#  (25.591, 'Provo'),
#  (27.336, 'Torrance'),
#  (22.465, 'Fairfield'),
#  (27.257, 'West Jordan'),
#  (23.106, 'Chula Vista'),
#  (27.336, 'Pomona'),
#  (18.416, 'Tacoma'),
#  (30.833, 'Alexandria'),
#  (30.134, 'Hialeah'),
#  (24.511, 'Highlands Ranch'),
#  (26.773, 'Pueblo'),
#  (25.014, 'Modesto'),
#  (29.3, 'Cape Coral'),
#  (28.313, 'Ann Arbor'),
#  (30.362, 'Kansas City'),
#  (27.981, 'Lansing'),
#  (32.738, 'Tampa'),
#  (29.334, 'Aurora'),
#  (32.534, 'Birmingham'),
#  (31.694, 'Newport News'),
# ...

# %%
# %sql select iata, port_city, port_state,count(*) from immigrations i join ports p on p.port_code=i.iata join   group by iata, port_city, port_state order by count(*) desc limit 10
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(27.0, 2016.0, 4.0, 101.0, 101.0, 'BOS', '1956-03-31 00:00:00', 1.0, 'MA', '1956-04-04 00:00:00', 58.0, 1.0, 1.0, '20160401', 'G', 'O', 'M', 1958.0, '04062016', 'M', 'LH', 92478763830.0, '00422', 'B1'),
#  (28.0, 2016.0, 4.0, 101.0, 101.0, 'ATL', '1956-03-31 00:00:00', 1.0, 'MA', '1956-04-04 00:00:00', 56.0, 1.0, 1.0, '20160401', 'G', 'O', 'M', 1960.0, '04062016', 'F', 'LH', 92478900330.0, '00422', 'B1'),
#  (29.0, 2016.0, 4.0, 101.0, 101.0, 'ATL', '1956-03-31 00:00:00', 1.0, 'MA', '1956-04-16 00:00:00', 62.0, 2.0, 1.0, '20160401', 'G', 'O', 'M', 1954.0, '09302016', 'M', 'AZ', 92503781430.0, '00614', 'B2'),
#  (30.0, 2016.0, 4.0, 101.0, 101.0, 'ATL', '1956-03-31 00:00:00', 1.0, 'NJ', '1956-05-03 00:00:00', 49.0, 2.0, 1.0, '20160401', 'G', 'O', 'M', 1967.0, '09302016', 'M', 'OS', 92470209430.0, '00089', 'B2'),
# ...

# %%
import pandas as pd
import datetime as dt

player_list = [20573.0,20551.0,20545.0]
  
# creating a pandas dataframe
df = pd.DataFrame(player_list,columns=['Dates'])



#df['Dates'] = pd.to_datetime(df['Dates'], format='%Y%m%d') 
df['Dates'] = pd.TimedeltaIndex(df['Dates'], unit='d') + dt.datetime(1899, 12, 30)

print(df)
# Out:
#        Dates
# 0 1956-04-28
# 1 1956-04-06
# 2 1956-03-31

# %%
# %sql select count(*) from temperature
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(661524,)]
